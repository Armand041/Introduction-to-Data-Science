# %% [markdown]
# # 1. Introduction

# %% [markdown]
# This notebook is dedicated to a basic study of Artificial Intelligence through the usage of free external tools and materials. All resources used will be linked in their respective fragments.

# %% [markdown]
# ## 1.1. Who am I?

# %% [markdown]
# I'm an student in the [<ins>degree in Engineering in Artificial Intelligence</ins>](https://web.ua.es/es/grados/grado-en-ingenieria-en-inteligencia-artificial/), from the [<ins>University of Alacant</ins>](https://www.ua.es/).
#
# - Daniel Paredes Valverde
#
#   -> GitHub Profile: [<ins>Armand041</ins>](https://github.com/Armand041)
#
#   -> Contact E-mail: <ins>dpv20@alu.ua.es</ins>

# %% [markdown]
# ## 1.2. External Tools and Materials

# %% [markdown]
# We are mainly going to be referencing the work of the spanish content creator [<ins>dotCSV</ins>](https://www.youtube.com/@DotCSV), however, we will also be using and experimenting with the [<ins>Kaggle</ins>](https://www.kaggle.com/) platform.
#
# We will be following the video list of [<ins>👨‍💻 Aprende Inteligencia Artificial</ins>](https://www.youtube.com/playlist?list=PL-Ogd76BhmcC_E2RjgIIJZd1DQdYHcVf0) as a theorical guide. On the other hand, the list [<ins>💻 IA Notebooks</ins>](https://www.youtube.com/playlist?list=PL-Ogd76BhmcCO4VeOlIH93BMT5A_kKAXp) will be used as the practical implementation. Lastly, [<ins>Kaggle</ins>](https://www.kaggle.com/), will be fundamental to test our skills on what we have learned, using a variety of data and exercises.
#
# We will summarize and expand the contents of this tools. However, we highly recommend reviewing them from the original source, as they are excellent works made by highly invested people.

# %% [markdown]
# # 2. Lexic
#
# <!-- Lexic Structure
# / First Block /
# Line above video title
# Video Title with hyperlink to the video
# Video Title translation
# Line below video title
#
# / Second Block /
# Important word in bold -> Description (Additional reference, if needed)
# -->

# %% [markdown]
# ----
# #### What is Machine Learning? And Deep Learning? A conceptual map | DotCSV
#
# _[<ins>¿Qué es el Machine Learning?¿Y Deep Learning? Un mapa conceptual | DotCSV</ins>](https://www.youtube.com/watch?v=KytW151dpqU&list=PL-Ogd76BhmcC_E2RjgIIJZd1DQdYHcVf0)_
#
# ----

# %% [markdown]
# **Artificial Intelligence (AI)** -> Computer Science sector that centers around the idea of creating machines capable of apparent intelligence. It can also refer to the characteristic of a machine to appear intelligent.
#
# **Weak AI** -> AIs that are capable of performing a compact list of tasks, failing dramatically if asked to make a task out of their scope.
#
# **Strong AI** -> AIs capable of performing a big list of tasks. They are only a theorical type of AI, as no such example have yet arrived, but they are presumed to be self-aware and capable of human-like reasoning [[<ins>1</ins>](https://www.ibm.com/think/topics/strong-ai)].
#
# **Machine Learning** -> **Artificial Intelligence** sector that seeks to teach AI machines behaviours or tasks based in experience. Their ultimate goal is not to have a machine capable of performing an specific task, instead, they specialize in teaching the machine to learn by itself the desired task. There are three main ways to make this: **Supervised Learning**, **Unsupervised Learning** and **Reinforced Learning**.
#
# **Neural Network** -> Technic inside the **Machine Learning** sector, centered around the idea of hierarchical learning. In this method the layers go from more concrete to more abstract, adding complexity in each layer. There is no limit to the number of layers that a Neural Network can muster. When a Neural Network has lots of layers, it is considered as a **Deep Learning** algorithm.
#
# **Big Data** -> Huge quantities of data. Also references the process of analysing and processing it. It forms a symbiosis relationship with AI, as **Big Data** profits from the capacities of technics such as **Deep Learning**, and the majority of **Machine Learning** needs the data provided by **Big Data** to evolve and grow [[<ins>2</ins>](https://www.panel-ialab.com/en/blog/relacion-ia-big-data/)].

# %% [markdown]
# ----
# #### What is Supervised and Unsupervised Learning? | DotCSV
#
# _[<ins>¿Qué es el Aprendizaje Supervisado y No Supervisado? | DotCSV</ins>](https://www.youtube.com/watch?v=oT3arRRB2Cw&list=PL-Ogd76BhmcC_E2RjgIIJZd1DQdYHcVf0&index=2)_
#
# ----

# %% [markdown]
# **Supervised Learning** -> Type of learning paradigm, used in **Machine Learning**. Finds the pattern or relationship between an input and an output. It needs an initial batch of, normally, handmade pairs of inputs and outputs. When the AI is fed this initial batch, it should detect the relationship and start creating the correct outputs for new, neverseen, inputs.
#
# **Unsupervised Learning** -> Type of learning paradigm, used in **Machine Learning**. It generates knowledge only by processing the inputs, without the need of an initial batch of examples. An example of **unsupervised learning** would be a **clustering**  problem.
#
# **Clustering** -> It refers to a type of **unsupervised learning** that centers around the problem of optimally grouping a batch of inputs. In other words, it orders the input based in similarities in their properties and characteristics. The number of groups or **clusters** is one of the main focuses of this practice [[<ins>3</ins>](https://www.ibm.com/think/topics/clustering)].
#
# **Latent Space** -> It is a mathematical space that represents the underlying structure of inputs. Each dimension is configured in one underlying feature, making spaces have many more dimensions that we can comprehend. This help us to generate and learn about similar objects and group up inputs more effectively, even allowing us to make mathematical operations with them [[<ins>4</ins>](https://www.ibm.com/think/topics/latent-space)].

# %% [markdown]
# ----
# #### Models to comprehend the chaotic reality | DotCSV
#
# _[<ins>Modelos para entender una realidad caótica | DotCSV</ins>](https://www.youtube.com/watch?v=Sb8XVheowVQ&list=PL-Ogd76BhmcC_E2RjgIIJZd1DQdYHcVf0&index=3)_
#
# ----

# %% [markdown]
# **Model** -> Simplified representations of reality. They aim to balance information representation with easy reading and usage. Some examples of models are maps, diagrams and music sheets. As the model is a simplification of reality, it should aim to represent the experimental data. We need to minimize the error between the experimental data and the model, changing its parameter. Once the error is minimum, we can learn about new scenarios.
#
# **Probabilistic Model** -> Instead of creating a complex **model** that includes lots and lots of exceptions, we can instead create a **probabilistic model** that encapsulates the chances. Instead of listing the exceptions to a kid passing the exam such as 'did not study', 'fell asleep'... we can say that 90% of kids passed the exam. This reduces the complexity of the model whilst maintaning relevant information.
#
# **Error Function** -> Every **model** should have an **error function** that determines how well it performs based on the data provided. This function follows optimization principals, such as **linear regression**, and it should aim to be near 0.

# %% [markdown]
# # 3. Learning Paradigms
# <!-- General Content Block Structure
# / Introduction Block /
# Content
#
# / Theorical Blocks /
# Content
#
# / Practical Blocks /
# Content
#
# / Video References Block 1 /
# Line above title
# 'Videos Referenced'
# Line below title
#
# / Video References Block 2 /
# List of videos referenced
# -->

# %% [markdown]
# There are 3 main **Learning Paradigms** in actual **Machine Learning**: **Supervised Leraning**, **Unsupervised Learning** and **Reinforced Learning**. In this section we will talk about the first two paradigms, but we will view them as 'black boxes'. In other words, we will learn what they are capable of and their characteristics without entering in the details of how they do it.

# %% [markdown]
# ## 3.1. Supervised Learning

# %% [markdown]
# **Supervised Learning** is one of the most common types of learning paradigms, but it often requires the most resources to work and function correctly, as it normally needs human interaction to iniate its learning process.

# %% [markdown]
# ### 3.1.1. Theory

# %% [markdown]
# **Supervised Learning** finds patterns or relationships between pairs of inputs and outputs. It is called supervised as, normally, human interaction is needed to train the algorithm. The task of the human trainer, from now on the **teacher**, will be to feed the algorithm inputs and their respective outputs. This initial batch of information will help the AI to learn the relationship between them, enabling it to generalize the knowledge and use it in new, neverseen, inputs.
#
# Let us see an example to better understand the concept:

# %% [markdown]
# |Input|Output|
# |-|-|
# |1|1|
# |2|4|
# |3|9|
# |6|36|
# |8|64|
# |11|121|
# |20|400|

# %% [markdown]
# Given this initial batch, we, as humans, can clearly see a pattern pop up. The output is the input multiplied by itself (its square number). So, if new input arrived such as the number 7, we could apply the generalization we just made and provide the output 49.
#
# In a more programatic way, we could say the following:

# %%
def generalization(n: int) -> int:
    '''
    Given an integer input, return the squared input

    n: input
        -> Integer number that represents the input of a AI using supervised learning
    '''

    return n**2

# %%
print(f'Input: 7 -> Output: {generalization(7)}')
print(f'Input: 15 -> Output: {generalization(15)}')
print(f'Input: 25 -> Output: {generalization(25)}')
print(f'Input: 100 -> Output: {generalization(100)}')
# Out:
# Input: 7 -> Output: 49
# Input: 15 -> Output: 225
# Input: 25 -> Output: 625
# Input: 100 -> Output: 10000

# %% [markdown]
# This can be applied to any input-output situation, wether e-mails are spam or not, if a student is going to pass or fail exams based on their notes, what is the favourite candy of a kid given its favourite sport... If there is any pattern or relationship between the input and the output (and given enough examples by the teacher), the algorithm will find it.
#
# It is a heavily used learning paradigm, and for good reasons, but, as we saw, it comes with a hefty price. It requires a teacher to manually process some quantity of the data, normally around 20% of it. The more data we manually process, the better the algorithm will perform, so it is a question of how much time and labour are we willing to invest in the learning batch of data and what precision of the output we desired.

# %% [markdown]
# ## 3.2. Unsupervised Learning

# %% [markdown]
# Contrary to **supervised learning**, it does not require an initial batch of input-output examples to function. It is this characteristic that makes this language paradigm essential in the future of **machine learning**.

# %% [markdown]
# ### 3.2.1. Theory

# %% [markdown]
# **Unsupervised Learning** finds the internal structure of the inputs, creating and forming patterns of similitude between the inputs. The more complex algorithms can determine the underlying structure and characteristics of the inputs, creating what is called a **Latent Space**. This way they are capable of generating and learning about similar inputs, creating a complex network of relations that allows us to mathematically operate them.
#
# One of the most common problems of **Unsupervised Learning** are the **Clustering** problems. This problems study the optimal way to divide in groups a set of inputs. Let us see a **clustering** example to visualize this learning paradigm:

# %% [markdown]
# Input -> a, b, 1, 5, c, e, 8, f, 6, 4
#
# Option 1, dividing in letters and numbers:
#
#     First Cluster: a, b, c, e, f
#
#     Second Cluster: 1, 5, 8, 6, 4
#
# Option 2, dividing in vowels, consonants, evens and odds
#
#     First CLuster: a, e
#
#     Second Cluster: b, c, f
#
#     Third Cluster: 8, 6, 4
#
#     Fourth CLuster: 1, 5

# %% [markdown]
# Having more **clusters** makes for a more concrete division, however, if we keep increasing them we may run into an algorithm too individualistic to form meaningful connections. This would waste resources and defeat the focus of **clustering** problems. Studying the optimal number of **clusters** is essential for a good algorithm.
#
# This way of learning is much cheaper than **Supervised Learning**, but the results are impossible to verify, as it does not follow an input-output basis. This type of algorithm is essential in generative AI, as it mathematically approaches the inputs, creating **latent spaces** that organize the information by similarities in their underlying structure. Substracting, adding and multiplying the vectors inside this mathematical space transforms the input into the output.

# %% [markdown]
# ----
# ## Referenced Videos
# ----

# %% [markdown]
# [<ins>¿Qué es el Aprendizaje Supervisado y No Supervisado? | DotCSV</ins>](https://www.youtube.com/watch?v=oT3arRRB2Cw&list=PL-Ogd76BhmcC_E2RjgIIJZd1DQdYHcVf0&index=2) / _What is Supervised and Unsupervised Learning? | DotCSV_

# %% [markdown]
# # 4. Neural Networks
# <!-- General Content Block Structure
# / Introduction Block /
# Content
#
# / Theorical Blocks /
# Content
#
# / Practical Blocks /
# Content
#
# / Video References Block 1 /
# Line above title
# 'Videos Referenced'
# Line below title
#
# / Video References Block 2 /
# List of videos referenced
# -->

# %% [markdown]
# In this section we will talk about one of the most important structures in today's **Machine Learning** algorithms: **Neural Networks**. First, we will review briefly the concepts of **Model** and error optimization.

# %% [markdown]
# ## 4.1. Models and Probabilistic Models

# %% [markdown]
# To understand our complex world, we make use of simplified versions of it. Diagrams, musical sheets, maps... they all are models to a more difficult to understand reality. The objective of a model is to balance the precision when representing reality with enough simplicity to be effective.
#
# For example, the maps lack a 100% precision when representing reality, as the depth, colors and textures are often lost in a 2D map. However, this imprecission is acceptable for the sake of simplicity and effectivity when using it.
#
# ![image.png](attachment:4e16db2c-0ee9-4d18-88d4-1346223b02c7.png)
#
# When we start to model real life, we might encounter with a problem: too much complexity. We can try to model students passing exams, but we rapidly encounter exceptions upon exceptions. The model could be the next one:
#
# 'A student passes the exam if they have...
#
#     -> studied
#
#     -> slept well
#
#     -> have a fondness for the subject
#
#     -> has not received negative news in the past week
#
#     -> copied and not get caught
#
#     -> ...'
#
# The list can go on and on, adding exceptions (or **Parameters** as we will learn in the next section) to try reaching the 100% reality precision, but the complexity of the model will also increase.  This creates a flawed way of modelling, as too much complexity can render useless any effort of computing or creating the models. Instead, we can use **Probabilistic Models** as a short-cut to reduce complexity whilst maintaining a relatively high fidelity to reality.
#
# Now, instead of saying a long list of requirements to pass the exam, we can simply say the probability of passing it:
#
# 'A student has an 85% probability of passing the exam'
#
# They can also be combined, having the probability tied with some important exceptions such as the following example:
#
# 'A student that has...
#
#     -> studied
#
#     -> slept well
#
# has an 95% of probability of passing the test'
#
# Both ways of modelling have their strengths and weaknesses, so each one can come in handy when reviewing certain parts of real life. However, they share some objectives and characteristics that we will study and review in the next parts: **Error Function** and **Error Optimization**.

# %% [markdown]
# ## 4.2. Data in Models

# %% [markdown]
# When talking about **Models**, it is essential to talk about data and parameters within the reach of the model. As we saw in the previous section, we can feed the model with exceptions, or, to be more precise, **Parameters**.
#
# We will start by creating a simple model to understand the importance of **Parameters** and **Multidimensionality**. The model will be the students passing an exam based on their study time, in other words, our parameters will be study time and passing the exam.

# %%
import matplotlib.pyplot as plt

# Study time in hours
study_time = [1, 2, 3, 5, 7, 8.5]
# Passed the exam (1) or not (0)
passed = [0, 0, 0, 0, 1, 1]

# Create the frame
plt.figure(figsize =(10,2.5))

# Plot the data
plt.scatter(study_time, passed)

# Set the axis labels
plt.xlabel('Study Time (h)')
plt.ylabel('Passed (1/0)')

# Show the plot
plt.show()

# %% [markdown]
# We can represent the two parameters (Passed and Study Time) in a 2 dimensional graph. We can adjust this parameters to better fit the reality, however, this may fall of short. If this happens, we need to increase the number of parameters, increasing the number of dimensions needed to represent them.
#
# Let us run again the same model, but adding a third parameter: Time Slept.

# %%
import matplotlib.pyplot as plt

# Study time in hours
study_time = [1, 2, 3, 5, 7, 8.5]
# Passed the exam (1) or not (0)
passed = [0, 1, 0, 1, 1, 0]
# Slept Time in hours
time_slept = [8, 7, 5, 8, 6.5, 3]

# Create the frame
fig = plt.figure(figsize =(5,5))
ax = fig.add_subplot(111, projection= '3d')

# Plot the data
ax.scatter(passed, study_time, time_slept)

# Set the axis labels
ax.set_xlabel('Passed (1/0)')
ax.set_ylabel('Study Time (h)')
ax.set_zlabel('Time Slept (h)', labelpad=-3)

# Show the plot
plt.show()

# %% [markdown]
# From this point on, adding parameters will only increase the **dimensionality** of the data, making it harder and harder to visualize. However, mathematically speaking, adding dimensions does little impact in the complexity. From this point on, we will see the data as points on a vector map, with as many dimensions as **parameters**.

# %% [markdown]
# # . References

# %% [markdown]
# - [<ins>1</ins>](https://www.ibm.com/think/topics/strong-ai) IBM, _Strong AI_, 2021
# - [<ins>2</ins>](https://www.panel-ialab.com/en/blog/relacion-ia-big-data/) Panel, _AI and Big Data: the keys to their relationship_, 2023
# - [<ins>3</ins>](https://www.ibm.com/think/topics/clustering) IBM, _Clustering_, 2024
# - [<ins>4</ins>](https://www.ibm.com/think/topics/latent-space) IBM, _Latent Space_, 2025
